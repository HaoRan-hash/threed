# %%
import torch

# %%
ckpt = torch.load('../point_transformer/partseg/pointTR_partseg.pth')
# ckpt = torch.load('../pointnet++/partseg/memorynet_19_partseg.pth')

# %%
print(type(ckpt))
# Out:
# <class 'dict'>

# %%
for key, value in ckpt.items():
    if key == 'model_state_dict':
        print(len(value.items()))
        for sub_key, _ in value.items():
            print(sub_key)
# Out:
# 526
# backbone.mlp.0.weight
# backbone.mlp.0.bias
# backbone.mlp.2.weight
# backbone.mlp.2.bias
# backbone.transformer_layer.linear_in.0.weight
# backbone.transformer_layer.linear_in.0.bias
# backbone.transformer_layer.linear_in.1.weight
# backbone.transformer_layer.linear_in.1.bias
# backbone.transformer_layer.linear_in.1.running_mean
# backbone.transformer_layer.linear_in.1.running_var
# backbone.transformer_layer.linear_in.1.num_batches_tracked
# backbone.transformer_layer.linear_out.0.weight
# backbone.transformer_layer.linear_out.0.bias
# backbone.transformer_layer.linear_out.1.weight
# backbone.transformer_layer.linear_out.1.bias
# backbone.transformer_layer.linear_out.1.running_mean
# backbone.transformer_layer.linear_out.1.running_var
# backbone.transformer_layer.linear_out.1.num_batches_tracked
# backbone.transformer_layer.q_proj.weight
# backbone.transformer_layer.q_proj.bias
# backbone.transformer_layer.k_proj.weight
# backbone.transformer_layer.k_proj.bias
# ...
